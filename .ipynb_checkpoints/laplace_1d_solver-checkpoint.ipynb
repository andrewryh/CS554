# %%
# %matplotlib notebook 
import numpy as np
from scipy.sparse import spdiags
import matplotlib.pyplot as plt
from scipy.sparse.linalg import spsolve
 
n=4
 
# boundary conditions
u = np.ones(n+1) 
u[0]=1
u[n]=2

for k in range(100)
    u_prev = u
    u[:] = 
 
#print b
 
# plot
 
CS=plt.plot(x,b)
plt.show()
plt.xlabel("x")
plt.ylabel("y",rotation="horizontal",labelpad=20)
# Out:
# /home/andrei2/anaconda3/lib/python3.5/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:101: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# <img src="data:image/png;base64,...">
