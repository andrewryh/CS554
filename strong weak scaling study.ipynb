# %%
# %matplotlib notebook 
# Import modules
import math
import numpy as np
import matplotlib.pyplot
# Initialize figure
fig = matplotlib.pyplot.figure(1)
ax = fig.add_subplot(111)
ax.grid(True)
p_s = np.array([4, 8, 12, 16, 24, 48, 72])
p_w = np.array([4, 8, 12, 16, 24, 48])
t_s_1 = np.array([1*60+19, 44, 29, 26, 16, 1*60+39, 1*60+29])
t_s_2 = np.array([2*60+48, 1*60+38, 57, 43, 32, 18, 12])
t_s = [t_s_1,t_s_2]

t_w_1 = np.array([32, 34, 34, 35, 36, 1*60+45])
t_w_2 = np.array([68, 69, 68, 69, 2*60+46, 2*60+47])
t_w = [t_w_1, t_w_2]
for n in [1,2]:
    #ax.plot(p_s, t_s[n-1], '+--', label= "{:<5.3g}".format(n*5120000) + ' grid-points')
    ax.plot(p_w, t_w[n-1], '+--', label= "{:<5.3g}".format(n*512000) + ' grid-points per core')
    #+ \
         #%',dt=' + "{:<3.2g}".format(t_end/nt) + ',theta=' + "{:<5.4g}".format((a*t_end/nt)/(dx_n**2)))
print (t_s)    
ax.legend(loc=0)
ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_xlim(4, 48)
ax.set_ylabel('Time [s]')
ax.set_xlabel('Number of processors')
#ax.set_title('Fig 2. Weak scaling experimental study')
fig.show()
#fig.savefig('Figure_2.png')
# Out:
# <img src="data:image/png;base64,...">
# [array([79, 44, 29, 26, 16, 99, 89]), array([168,  98,  57,  43,  32,  18,  12])]
