# %%
# %matplotlib notebook 
# Import modules
import math
import numpy as np
import matplotlib.pyplot

# Initialize figure
fig = matplotlib.pyplot.figure(1)
ax = fig.add_subplot(111)
ax.grid(True)
#p_s = np.array([32, 64, 96, 128])
p_s = np.array([16, 32, 64, 96, 128, 256])
#p_s_in = np.array([4, 8, 16, 32])
p_s_in = np.array([1, 2, 4, 8, 16, 32])
p_s_ex = np.array([1, 2, 4, 8, 12, 16, 24])
p_w_in = np.array([1, 2, 4, 8, 16, 32, 64, 128])
t_s_1 = np.array([3913.7, 1257.86, 822.214, 673.838])
t_s_2 = np.array([76.26, 36.43, 25.7, 24.3, 22.9, 21.7])
#t_s_in = np.array([891, 247.5, 76.26, 36.43])
#t_s_in = np.array([[288.083, 245.883, 144.089, 94.2994, 75.4662, 66.4237],
#                  [85.2109, 95.5891, 65.993, 58.6522, 52.0827, 56.0407]])
t_s_in = np.array([[321.392, 200.223, 106.816, 64.1205, 39.8345, 29.5844],
                   [839.902, 431.574, 222.581, 129.552, 78.929,  57.9876],
                   [2564.65, 1027.91, 489.497, 278.561, 165.323, 119.341],
                   [15032.5, 3446.2, 1574.03, 795.105, 427.297, 292.577]])
t_s_ex = np.array([[100.678, 36.32, 25.5545, 22.4708, 22.4271, 22.3524, 23.1525],
                   [555.039, 168.216, 65.1022, 51.1026, 45.7816, 45.0599, 46.8443],
                   [3100.21, 661.64, 232.768, 102.511, 92.0645, 89.6484, 88.4777],
                   [9300,    3230,   992.451, 322.509, 274.217, 241.929, 226.18]])

t_s = [t_s_1,t_s_2]
t_s_ideal_extra = p_s[0]*t_s_2[0]/p_s
t_s_ideal_intra = t_s_in[3]/p_s_in

dim = np.array([2820,5640,11280,28200])
dim_ex = np.array([86655, 173310, 317735, 664355])

t_w_in = np.array([[54.8776, 71.3746, 77.7507, 88.8852, 113.86, 169.745, 268.009, 524.355],
                   [97.1648, 138.56, 157.285, 192.859, 245.88, 311.716, 525.424, 927.954],
                   [207.85, 298.929, 346.013, 423.004, 499.774, 647.586, 1117.02],
                   [534.347, 689.319, 770.253, 961.322, 1197.43, 1473.74]])
#t_w_2 = np.array([68, 69, 68, 69, 2*60+46, 2*60+47])
#t_w = [t_w_1, t_w_2]
dim_w = np.array([581, 985, 1970, 3940])
for n in [0,1,2,3]:
    #ax.plot(p_s, t_s_2, '+--', color="blue",linewidth=2, label= "{:<5.3g}".format(n) + ' elements')
    #ax.plot(p_s, t_s_ideal, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    ax.plot(p_s_in, t_s_in[n], '+--', linewidth=2, label= "{:<5.3g}".format(dim[n]) + ' elements')
#ax.plot(p_s_in, t_s_ideal_intra, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    #ax.plot(p_w, t_w[n-1], '+--', label= "{:<5.3g}".format(n*512000) + ' grid-points per core')
    #+ \
         #%',dt=' + "{:<3.2g}".format(t_end/nt) + ',theta=' + "{:<5.4g}".format((a*t_end/nt)/(dx_n**2)))
#print (t_s_ideal)    
#print (t_s_2)    
ax.legend(loc=0)
#ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_xlim(1, 16)
ax.set_ylim(1, 14000)
ax.xaxis.set_ticks(p_s_in)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel('Solution time (s)', fontsize=18)
ax.set_xlabel('Number of processors', fontsize=18)
#ax.set_title('Fig 1. Intra-node strong scaling {total execution time)}')
fig.show()
#fig.savefig('intra_node.png')

# Initialize figure
fig2 = matplotlib.pyplot.figure(2)
ax = fig2.add_subplot(111)
ax.grid(True)
for n in [0,1,2,3]:
    #ax.plot(p_s, t_s_2, '+--', color="blue",linewidth=2, label= "{:<5.3g}".format(n) + ' elements')
    #ax.plot(p_s, t_s_ideal, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    ax.loglog(p_s_in, t_s_in[n]/dim[n], '+--', linewidth=2, label= "{:<5.3g}".format(dim[n]) + ' elements')
#ax.plot(p_s_in, t_s_ideal_intra/dim[3], '+--', color="#ff8100",linewidth=2, label= 'ideal')
    #ax.plot(p_w, t_w[n-1], '+--', label= "{:<5.3g}".format(n*512000) + ' grid-points per core')
    #+ \
         #%',dt=' + "{:<3.2g}".format(t_end/nt) + ',theta=' + "{:<5.4g}".format((a*t_end/nt)/(dx_n**2)))
#print (t_s_ideal)    
#print (t_s_2)    
ax.legend(loc=0)
#ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_ylim([1e-2, 5e-1])
ax.set_xlim(1e+0, 3.2e+1)
ax.xaxis.set_ticks([1, 10, 32])
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel('Solution time (s/element)', fontsize=18)
ax.set_xlabel('Number of processors', fontsize=18)
#ax.set_title('Fig 2. Intra-node strong scaling (execution time per element)')
fig2.show()
#fig.savefig('intra_node.png')

# Initialize figure
fig3 = matplotlib.pyplot.figure(3)
ax = fig3.add_subplot(111)
ax.grid(True)
for n in [0, 1, 2, 3]:
    #ax.plot(p_s, t_s_2, '+--', color="blue",linewidth=2, label= "{:<5.3g}".format(n) + ' elements')
    #ax.plot(p_s, t_s_ideal, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    ax.loglog(32*p_s_ex, (t_s_ex[n]/dim_ex[n]), '+--', linewidth=2, label= "{:<5.3g}".format(dim_ex[n]) + ' elements')
#ax.plot(p_s_in, t_s_ideal_intra, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    #ax.plot(p_w, t_w[n-1], '+--', label= "{:<5.3g}".format(n*512000) + ' grid-points per core')
    #+ \
         #%',dt=' + "{:<3.2g}".format(t_end/nt) + ',theta=' + "{:<5.4g}".format((a*t_end/nt)/(dx_n**2)))
#print (t_s_ideal)    
#print (t_s_2)    
ax.legend(loc=0)
#ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_ylim(2e-4, 1.7e-2)
ax.set_xlim(3.2e+1, 7.68e+2)
#ax.xaxis.set_ticks(32*p_s_ex)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.xaxis.set_ticks([32, 64, 128, 256, 768])
ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.2e'))
ax.set_ylabel('Solution time (s/element)', fontsize=18)
ax.set_xlabel('Number of processors', fontsize=18)
#ax.set_title('Fig 3. Extra-node strong scaling (execution time per element)')
fig3.show()

# Weak scaling
# Initialize figure
fig4 = matplotlib.pyplot.figure(4)
ax = fig4.add_subplot(111)
ax.grid(True)
for n in [0, 1]:
    #ax.plot(p_s, t_s_2, '+--', color="blue",linewidth=2, label= "{:<5.3g}".format(n) + ' elements')
    #ax.plot(p_s, t_s_ideal, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    ax.loglog(p_w_in, t_w_in[n]/dim_w[n], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[n]) + ' elements per core')
ax.loglog(np.array([1, 2, 4, 8, 16, 32, 64]), t_w_in[2]/dim_w[2], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[2]) + ' elements per core')
ax.loglog(np.array([1, 2, 4, 8, 16, 32]), t_w_in[3]/dim_w[3], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[3]) + ' elements per core')

ax.legend(loc=0)
#ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_ylim(0.07, 0.4)
ax.set_xlim(1,32)
ax.xaxis.set_ticks(np.array([1, 4, 8, 16, 32]))
ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1e'))
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel('Solution time (s/element)', fontsize=18)
ax.set_xlabel('Number of processors', fontsize=18)
#ax.set_title('Fig 4. Intra-node weak scaling (execution time per element)')
fig4.show()
# Initialize figure
fig5 = matplotlib.pyplot.figure(5)
ax = fig5.add_subplot(111)
ax.grid(True)
for n in [0, 1]:
    #ax.plot(p_s, t_s_2, '+--', color="blue",linewidth=2, label= "{:<5.3g}".format(n) + ' elements')
    #ax.plot(p_s, t_s_ideal, '+--', color="#ff8100",linewidth=2, label= 'ideal')
    ax.loglog(p_w_in, t_w_in[n]/dim_w[n], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[n]) + ' elements per core')
#ax.plot(np.array([1, 2, 4, 8, 16, 32, 64]), t_w_in[2]/dim_w[2], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[2]) + ' elements per core')
#ax.plot(np.array([1, 2, 4, 8, 16, 32]), t_w_in[3]/dim_w[3], '+--', linewidth=2, label= "{:<5.4g}".format(dim_w[3]) + ' elements per core')
ax.legend(loc=0)
#ax.set_ylim(ax.get_ylim()[::-1]) # flip y axis
ax.set_ylim(0.28, 0.95)
ax.set_xlim(32,128)
ax.xaxis.set_ticks(np.array([32, 64, 128]))
ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.2e'))
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel('Solution time (s/element)', fontsize=18)
ax.set_xlabel('Number of processors', fontsize=18)
#ax.set_title('Fig 5. Extra-node weak scaling (execution time per element)')
fig5.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
